# %%
num = 3.14, 2.718, 1.618, 0.577
avg = sum(num)/len(num)
print(avg)
# Out:
# 2.01325

# %%
fahrenheit=98.6
Celsius=(fahrenheit-32)*5/9
print(Celsius)
# Out:
# 37.0

# %%
p=1000
r=0.055
t=3
compund=p*(1+r)**t
print(compund)
# Out:
# 1174.2413749999998

# %%
a=3.5
b=4.5
c=(a**2+b**2)**0.5
print(c)
# Out:
# 5.70087712549569

# %%
num=3.14159
print(round(num,3))
# Out:
# 3.142

# %%
a=45
b=67
percentage= (a/b)*100
print(percentage)
# Out:
# 67.16417910447761

# %%
a=23.456
print(a**0.5)
# Out:
# 4.843139477652899

# %%
p=2500
r=6.5
t=2.5
si=(p*r*t)/100
print(si)
# Out:
# 406.25

# %%
a=45.7
r=a*((22/7)/180)
print(r)
# Out:
# 0.797936507936508
